# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
from tensorflow import keras
import warnings
warnings.filterwarnings('ignore', category=UserWarning)
from tensorflow.keras.losses import Huber
from sklearn.preprocessing import MinMaxScaler
# Out:
# 2023-12-12 11:02:43.509354: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-12 11:02:43.710922: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-12 11:02:44.367142: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-12-12 11:02:44.367226: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-12-12 11:02:44.367233: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# Baca data Excel
df_train = pd.read_excel('lomba/train_prepro.xlsx', index_col=0)
df_test = pd.read_excel('lomba/test_prepro.xlsx',  index_col=0)

# %%
df_train
# Out:
#         Make  Vehicle Class  Engine Size(L)  Cylinders  Transmission
# Id
# 1          7              6        0.526316   0.500000             3  \
# 2          4              6        0.905263   0.358668             3
# 3          2             10        0.715789   0.358668            23
# 4         11             11        0.418238   0.166667            13
# 5          1              3        0.421053   0.500000            13
# ...      ...            ...             ...        ...           ...
# 137137     2             10        0.418238   0.833333            15
# 137138     9              9        0.105263   0.166667            23
# 137139    17              2        0.168421   0.166667            17
# 137140    20              0        0.168421   0.166667            13
# 137141     1              2        0.315789   0.166667            19
#
#         Fuel Type      City   HighWay  Combination  CO2 Emissions(g/km)
# Id
# 1               3  0.222910  0.210274     0.263047                306.0
# 2               1  0.703560  1.000000     1.000000                283.0
# 3               4  0.043860  0.069521     0.437581                329.0
# 4               3  0.395769  0.544521     0.437581                270.0
# 5               4  0.519866  0.205479     0.484838                193.0
# ...           ...       ...       ...          ...                  ...
# 137137          4  0.869711  0.263699     0.775035                275.0
# 137138          3  0.167441  0.029795     0.137870                166.0
# 137139          3  0.077141  0.286986     0.188999                181.0
# 137140          3  0.296182  0.007534     0.223907                123.0
# 137141          3  0.086687  0.095890     0.107546                182.0
#
# [137141 rows x 10 columns]

# %%
df_test
# Out:
#         Make  Vehicle Class  Engine Size(L)  Cylinders  Transmission
# Id
# 137142     3              2        0.547368   0.358668            15  \
# 137143     7             15        0.568421   0.500000            13
# 137144    16             11        1.000000   0.358668            19
# 137145    14              2        0.757895   0.358668            15
# 137146     2             12        0.715789   0.833333            15
# ...      ...            ...             ...        ...           ...
# 195913    11             11        0.484211   0.358668             3
# 195914     7             11        0.126316   0.166667            13
# 195915     4             12        0.526316   0.358668             3
# 195916     7             11        0.842105   0.833333            13
# 195917     0             11        0.526316   0.500000            16
#
#         Fuel Type      City   HighWay  Combination
# Id
# 137142          3  0.402993  0.060616     0.329337
# 137143          3  0.544634  0.492466     0.635755
# 137144          3  0.632095  0.352397     0.636812
# 137145          4  0.433437  0.544521     0.577221
# 137146          4  1.000000  0.655822     1.000000
# ...           ...       ...       ...          ...
# 195913          3  0.473426  0.715753     0.685825
# 195914          3  0.159701  0.226027     0.222849
# 195915          3  0.373839  0.376712     0.453808
# 195916          3  0.217234  0.157192     0.234485
# 195917          4  0.512900  0.006507     0.386460
#
# [58776 rows x 9 columns]

# %%
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

# Pisahkan fitur dan target
X_train_scaled = df_train.iloc[:, :-1]
y_train_scaled = df_train.iloc[:, -1]

data_X_train_scaled = scaler_X.fit_transform(X_train_scaled)
data_y_train_scaled = scaler_y.fit_transform(np.array(y_train_scaled).reshape(-1, 1))

data_test_scaled = scaler_X.fit_transform(df_test)

# %%
X_train_reshape = data_X_train_scaled.reshape(data_X_train_scaled.shape[0], data_X_train_scaled.shape[1], 1)
X_test_reshape = data_test_scaled.reshape(data_test_scaled.shape[0], data_test_scaled.shape[1], 1)

# %%
from tensorflow.keras.metrics import RootMeanSquaredError
def modelnya():
    model = tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_reshape.shape[1], 1)),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu', kernel_regularizer='l2'),
    tf.keras.layers.Dense(1, activation='linear')  # Aktivasi 'linear' untuk regresi
    ])
    model.compile(optimizer='sgd', loss='mean_squared_error', metrics=[RootMeanSquaredError()])
    return model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
model = modelnya()
  # Definisikan callbacks
callbacks = [
        ModelCheckpoint(f'./logs/lomba/best_model.h5', monitor='val_loss', save_best_only=True),
        TensorBoard(log_dir=f'./logs/lomba', histogram_freq=1, write_graph=True, write_images=True)
    
    ]
history = model.fit(X_train_reshape, data_y_train_scaled, validation_split=0.1, batch_size=64, epochs=20,
                        verbose=2, callbacks=callbacks, workers=-1)
# Out:
# Epoch 1/20
# 1929/1929 - 5s - loss: 0.6725 - root_mean_squared_error: 0.0892 - val_loss: 0.4478 - val_root_mean_squared_error: 0.0840 - 5s/epoch - 3ms/step
# Epoch 2/20
# 1929/1929 - 4s - loss: 0.3146 - root_mean_squared_error: 0.0849 - val_loss: 0.2110 - val_root_mean_squared_error: 0.0837 - 4s/epoch - 2ms/step
# Epoch 3/20
# 1929/1929 - 4s - loss: 0.1496 - root_mean_squared_error: 0.0849 - val_loss: 0.1016 - val_root_mean_squared_error: 0.0837 - 4s/epoch - 2ms/step
# Epoch 4/20
# 1929/1929 - 4s - loss: 0.0733 - root_mean_squared_error: 0.0848 - val_loss: 0.0510 - val_root_mean_squared_error: 0.0837 - 4s/epoch - 2ms/step
# Epoch 5/20
# 1929/1929 - 4s - loss: 0.0380 - root_mean_squared_error: 0.0847 - val_loss: 0.0276 - val_root_mean_squared_error: 0.0836 - 4s/epoch - 2ms/step
# Epoch 6/20
# 1929/1929 - 4s - loss: 0.0217 - root_mean_squared_error: 0.0846 - val_loss: 0.0168 - val_root_mean_squared_error: 0.0836 - 4s/epoch - 2ms/step
# Epoch 7/20
# 1929/1929 - 9s - loss: 0.0141 - root_mean_squared_error: 0.0846 - val_loss: 0.0117 - val_root_mean_squared_error: 0.0834 - 9s/epoch - 5ms/step
# Epoch 8/20
# 1929/1929 - 4s - loss: 0.0106 - root_mean_squared_error: 0.0845 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0833 - 4s/epoch - 2ms/step
# Epoch 9/20
# 1929/1929 - 4s - loss: 0.0090 - root_mean_squared_error: 0.0844 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0833 - 4s/epoch - 2ms/step
# Epoch 10/20
# 1929/1929 - 4s - loss: 0.0082 - root_mean_squared_error: 0.0844 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0835 - 4s/epoch - 2ms/step
# Epoch 11/20
# 1929/1929 - 4s - loss: 0.0078 - root_mean_squared_error: 0.0843 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0832 - 4s/epoch - 2ms/step
# Epoch 12/20
# 1929/1929 - 4s - loss: 0.0076 - root_mean_squared_error: 0.0842 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0831 - 4s/epoch - 2ms/step
# Epoch 13/20
# 1929/1929 - 4s - loss: 0.0075 - root_mean_squared_error: 0.0842 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0837 - 4s/epoch - 2ms/step
# Epoch 14/20
# 1929/1929 - 4s - loss: 0.0075 - root_mean_squared_error: 0.0842 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0832 - 4s/epoch - 2ms/step
# Epoch 15/20
# 1929/1929 - 4s - loss: 0.0074 - root_mean_squared_error: 0.0841 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0831 - 4s/epoch - 2ms/step
# Epoch 16/20
# 1929/1929 - 4s - loss: 0.0074 - root_mean_squared_error: 0.0841 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0829 - 4s/epoch - 2ms/step
# Epoch 17/20
# 1929/1929 - 4s - loss: 0.0074 - root_mean_squared_error: 0.0840 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0828 - 4s/epoch - 2ms/step
# Epoch 18/20
# 1929/1929 - 4s - loss: 0.0074 - root_mean_squared_error: 0.0840 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0828 - 4s/epoch - 2ms/step
# Epoch 19/20
# 1929/1929 - 4s - loss: 0.0074 - root_mean_squared_error: 0.0840 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0828 - 4s/epoch - 2ms/step
# Epoch 20/20
# 1929/1929 - 4s - loss: 0.0074 - root_mean_squared_error: 0.0839 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0828 - 4s/epoch - 2ms/step

# %%
# Plot Loss dan Validation Loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Train and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot Loss dan Validation Loss
plt.plot(history.history['root_mean_squared_error'], label='Train rmse')
plt.plot(history.history['val_root_mean_squared_error'], label='Validation rmse')
plt.title('Train and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import tensorflow as tf
model_best = tf.keras.models.load_model(f'logs/lomba/best_model.h5')

# %%
# Prediksi menggunakan model
predictions = model.predict(X_test_reshape)
# Out:
# 1837/1837 [==============================] - 2s 1ms/step

# %%
balikan_prediksi = scaler_y.inverse_transform(predictions).astype(int)
predictions_float = balikan_prediksi.astype(float)

# %%
predictions_float.shape , df_test.shape
# Out:
# ((58776, 1), (58776, 9))

# %%
df_test_no_index  = df_test.reset_index(drop=True)
df_test_no_index
# Out:
#        Make  Vehicle Class  Engine Size(L)  Cylinders  Transmission
# 0         3              2        0.547368   0.358668            15  \
# 1         7             15        0.568421   0.500000            13
# 2        16             11        1.000000   0.358668            19
# 3        14              2        0.757895   0.358668            15
# 4         2             12        0.715789   0.833333            15
# ...     ...            ...             ...        ...           ...
# 58771    11             11        0.484211   0.358668             3
# 58772     7             11        0.126316   0.166667            13
# 58773     4             12        0.526316   0.358668             3
# 58774     7             11        0.842105   0.833333            13
# 58775     0             11        0.526316   0.500000            16
#
#        Fuel Type      City   HighWay  Combination
# 0              3  0.402993  0.060616     0.329337
# 1              3  0.544634  0.492466     0.635755
# 2              3  0.632095  0.352397     0.636812
# 3              4  0.433437  0.544521     0.577221
# 4              4  1.000000  0.655822     1.000000
# ...          ...       ...       ...          ...
# 58771          3  0.473426  0.715753     0.685825
# 58772          3  0.159701  0.226027     0.222849
# 58773          3  0.373839  0.376712     0.453808
# 58774          3  0.217234  0.157192     0.234485
# 58775          4  0.512900  0.006507     0.386460
#
# [58776 rows x 9 columns]

# %%
df_test
# Out:
#         Make  Vehicle Class  Engine Size(L)  Cylinders  Transmission
# Id
# 137142     3              2        0.547368   0.358668            15  \
# 137143     7             15        0.568421   0.500000            13
# 137144    16             11        1.000000   0.358668            19
# 137145    14              2        0.757895   0.358668            15
# 137146     2             12        0.715789   0.833333            15
# ...      ...            ...             ...        ...           ...
# 195913    11             11        0.484211   0.358668             3
# 195914     7             11        0.126316   0.166667            13
# 195915     4             12        0.526316   0.358668             3
# 195916     7             11        0.842105   0.833333            13
# 195917     0             11        0.526316   0.500000            16
#
#         Fuel Type      City   HighWay  Combination
# Id
# 137142          3  0.402993  0.060616     0.329337
# 137143          3  0.544634  0.492466     0.635755
# 137144          3  0.632095  0.352397     0.636812
# 137145          4  0.433437  0.544521     0.577221
# 137146          4  1.000000  0.655822     1.000000
# ...           ...       ...       ...          ...
# 195913          3  0.473426  0.715753     0.685825
# 195914          3  0.159701  0.226027     0.222849
# 195915          3  0.373839  0.376712     0.453808
# 195916          3  0.217234  0.157192     0.234485
# 195917          4  0.512900  0.006507     0.386460
#
# [58776 rows x 9 columns]

# %%
# Gabungkan hasil prediksi dengan DataFrame pengujian
result_df = pd.DataFrame(predictions_float, columns=['Predicted CO2 Emissions(g/km)'])
result_df
final_result = pd.concat([df_test_no_index, result_df], axis=1)
final_result
# Out:
#        Make  Vehicle Class  Engine Size(L)  Cylinders  Transmission
# 0         3              2        0.547368   0.358668            15  \
# 1         7             15        0.568421   0.500000            13
# 2        16             11        1.000000   0.358668            19
# 3        14              2        0.757895   0.358668            15
# 4         2             12        0.715789   0.833333            15
# ...     ...            ...             ...        ...           ...
# 58771    11             11        0.484211   0.358668             3
# 58772     7             11        0.126316   0.166667            13
# 58773     4             12        0.526316   0.358668             3
# 58774     7             11        0.842105   0.833333            13
# 58775     0             11        0.526316   0.500000            16
#
#        Fuel Type      City   HighWay  Combination
# 0              3  0.402993  0.060616     0.329337  \
# 1              3  0.544634  0.492466     0.635755
# 2              3  0.632095  0.352397     0.636812
# 3              4  0.433437  0.544521     0.577221
# 4              4  1.000000  0.655822     1.000000
# ...          ...       ...       ...          ...
# 58771          3  0.473426  0.715753     0.685825
# 58772          3  0.159701  0.226027     0.222849
# 58773          3  0.373839  0.376712     0.453808
# 58774          3  0.217234  0.157192     0.234485
# 58775          4  0.512900  0.006507     0.386460
#
#        Predicted CO2 Emissions(g/km)
# 0                              244.0
# 1                              295.0
# 2                              320.0
# 3                              276.0
# 4                              349.0
# ...                              ...
# 58771                          295.0
# 58772                          210.0
# 58773                          292.0
# 58774                          315.0
# 58775                          282.0
#
# [58776 rows x 10 columns]

# %%
result_df
# Out:
#        Predicted CO2 Emissions(g/km)
# 0                              244.0
# 1                              295.0
# 2                              320.0
# 3                              276.0
# 4                              349.0
# ...                              ...
# 58771                          295.0
# 58772                          210.0
# 58773                          292.0
# 58774                          315.0
# 58775                          282.0
#
# [58776 rows x 1 columns]
